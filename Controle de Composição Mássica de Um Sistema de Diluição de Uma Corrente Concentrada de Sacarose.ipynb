# %% [markdown]
# # Universidade Federal de Uberlândia
#
# ## Faculdade de Engenharia Química - Controle de Processos Químicos II

# %% [markdown]
# Um processo industrial utiliza um tanque de mistura alimentado por duas correntes com diferentes concentrações mássicas de sacarose para assegurar a consistência final do seu produto. Os valores do ponto de operação do sistema e estado estacionário estão apresentados na Tabela 1. Com base nessas informações deseja-se investigar o comportamento dinâmico do processo.

# %% [markdown]
# \begin{aligned}
# &\text {Tabela 1: Valores nominais para o ponto de operação. }\\
# &\begin{array}{|l|l|l|}
# \hline \text { Variável } & \text { Valor } & \text { Unidades } \\
# \hline \mathrm{F_1}  & 2,00 & \mathrm{~L} / \mathrm{min} \\
# \hline \mathrm{F_2}  & 3,00 & \mathrm{~L} / \mathrm{min} \\
# \hline \mathrm{C_1}  & 9,00 & \mathrm{~kg} / \mathrm{L} \\
# \hline \mathrm{C_2}  & 4,00 & \mathrm{~kg} / \mathrm{L} \\
# \hline \mathrm{V} & 10,0 & \mathrm{~L} \\
# \hline
# \end{array}
# \end{aligned}

# %% [markdown]
# # Item 1: Desenvolvimento do modelo do tanque de mistura para concentração de sacarose.
# Desenvolver o modelo do tanque de mistura para concentração mássica de sacarose na corrente de saída considerando que o sistema seja operado a volume constante. Liste os estados, as entradas e os parâmetros do processo. Considere $F_1 = F_{1(t)}$ (entrada manipulada) e $C_1 = C_{1(t)}$ (perturbação)

# %% [markdown]
# #### Balanço de Massa Global:
#
# $ m{\mid_{t+\Delta t}} = m{\mid_t} + \dot{m}_{entra} - \dot{m}_{sai} $ \
# \
# $\frac{m\mid_{t+\Delta t} - m{\mid_t}}{\Delta t} = \dot{m}_{entra} - \dot{m}_{sai}$ \
# \
# $ \frac{dm}{dt} = \dot{m}_{entra} - \dot{m}_{sai} $ \
# \
# mas: \
# \
# $ m = \rho  V$ \
# \
# $ \dot{m}_{entra} = \rho_i F_i$ \
# \
# $ \dot{m}_{sai} = \rho F$ \
# \
# Substituindo as expressões acima: \
# \
# $\frac{d(\rho V)}{dt} = \rho_i F_1 + \rho_i F_2 - \rho F$ \
# \
# Seja $\rho$ constante: \
# \
# $\rho \frac{dV}{dt} = \rho (F_1 + F_2 - F)$ \
# \
# $ V = cte $
#
# # $ F = F_1 + F_2 $

# %% [markdown]
# #### Balanço de massa para a sacarose:
#
# $ m{\mid_{t+\Delta t}} = m{\mid_t} + \dot{m}_{entra} - \dot{m}_{sai} + \dot{m}_{reage} $\
# \
# $ \frac{m{\mid_{t+\Delta t}}}{m{\mid_t}} = \Delta t ( \dot{m}_{entra} - \dot{m}_{sai} + \dot{m}_{reage}) $ \
# \
# $ \lim_{x\rightarrow\infty} (\frac{m{\mid_{t+\Delta t}}}{m{\mid_t}}) = \dot{m}_{entra} - \dot{m}_{sai} + \dot{m}_{reage} $ \
# \
# $ \frac{dm}{dt} = \dot{m}_{entra} - \dot{m}_{sai} + \dot{m}_{reage} $ \
# \
# Sabe-se que:\
# \
# $C = \frac{N}{V}$ \
# \
# $N = \frac{m}{MM}$ \
# \
# $m = C. V. MM $ \
# \
# $ \rho = \frac{m}{V}$ \
# \
# Pela hipótese de mistura perfeita temos que a concentração no volume de controle é a mesma da corrente de saída
# \
# \
# $m = C. F. {MM}$ \
# \
# Então:
# \
# \
# $ \frac{d(C_{out} V)}{dt} = C_1 F_1 + C_2 F_2 - C_{out} F$ \
# \
# $ [\frac{kg}{L}\frac{L}{min}] = [\frac{kg}{L} \frac{L}{min}] + [\frac{kg}{L} \frac{L}{min}] - [\frac{kg}{L} \frac{L}{min}]$ \
# \
# $\frac{kg}{min} = \frac{kg}{min}$ \
# \
# $C = C_{out}$ e V constante:
#
# $  V \frac{dC}{dt} = C_1 F_1  + C_2 F_2  - C F $ \
# \
# Pelo balanço de massa global: $ F = F_1 + F_2 $ \
# \
#  ${\frac{dC}{dt} = \frac{1}{V} (C_1 F_1  + C_2 F_2  - C F_1 + C F_2)} $ \
#
# # $\frac{dC}{dt} = \frac{F_1 (C_1 - C)  + F_2 (C_2  - C)}{V} $

# %% [markdown]
# ### Entradas
# $ F_1 $ \
# $ F_2 $ \
# $ C_1 $ \
# $ C_2 $
#
# ### Estados   (respostas das EDO´s)
# $C_{out}$
#
# ### Parâmetros
# $V$

# %% [markdown]
# # Item 2: Cálculo do estado estacionário:
# Apresente a equação do estado estacionário do modelo. Com base nos dados da Tabela 1, calcule o estado estacionário inicial do sistema.

# %% [markdown]
# Estado Estacionário: $ \frac{dC}{dt} = 0 $ \
# \
# $ \frac{dC}{dt} = \frac{1}{V} (C_1 F_1  + C_2 F_2  - C F) = 0 $ \
# \
# $ (C_1 F_1  + C_2 F_2  - C F) = 0 $\
# \
# $ C_1 F_1  + C_2 F_2  = C F $ \
# \
# $ C = \frac{C_1 F_1  + C_2 F_2}{F} $ \
# \
# mas : $ F = F_1 + F_2 $ \
# \
# $ C = \frac{C_1 F_1  + C_2 F_2}{F_1 + F_2} $ \
# \
# $ C = \frac{9,00 * 2,00  + 4,00 * 3,00}{2,00 + 3,00} $ \
# \
# $ C_{ss} = 6,0 \  kg/L $

# %% [markdown]
# # Item 3: Determinação das funções de transferência
#  Linearize o sistema caso necessário e apresente o modelo em função de transferência. Demonstre que o modelo em função de transferência é dado por:
#
# $C_{\text {out }}^{\prime}(s)=G_1(s) F_1^{\prime}(s)+G_2(s) C_1^{\prime}(s)$

# %% [markdown]
# $\frac{dC}{dt} = \frac{F_1 (C_1 - C)  + F_2 (C_2  - C)}{V} $ \
# \
# Termo não linear: $ F_{1(t)} ( C_{1(t)} - C_{(t)}) $ \
# \
# $ f = \frac{dC}{dt} = \frac{F_1 (C_1 - C)  + F_2 (C_2  - C)}{V} $ \
# \
# $ \frac{dC}{dt} \simeq f_{ss} + \frac{ \partial f}{\partial F_1} (F_1 - F_{1ss}) + \frac{ \partial f}{\partial C_1} (C_1 - C_{2ss}) + \frac{ \partial f}{\partial C} (C - C_{ss}) $ \
# \
# $  f_{ss} = 0 $

# %% [markdown]
# Aplicando La Place:

# %%
import sympy as sp

F1, C1, F2, C2, C, V = sp.symbols('F1 C1 F2 C2 C V')

dC_dt = (F1*(C1-C) + F2*(C2-C))/V

M = sp.Matrix([dC_dt])
J = M.jacobian([C1, F1, C])
J
# Out:
# Matrix([[F1/V, (-C + C1)/V, (-F1 - F2)/V]])

# %%
Jss = J.subs({F1 : 2.00, C1: 9.00, F2: 3.00, C2: 4.00, C: 6.00 , V: 10.00})
Jss
# Out:
# Matrix([[0.2, 0.3, -0.5]])

# %%
F1_desv, C1_desv, F2_desv, C2_desv, C_desv = sp.symbols('Ftilde1 Ctilde_1 Ftilde_2 Ctilde_2 Ctilde')

V =sp.Matrix([C1_desv, F1_desv, C_desv])
V
# Out:
# Matrix([
# [Ctilde_1],
# [ Ftilde1],
# [  Ctilde]])

# %%
Jss_desv = Jss*V
Jss_desv
# Out:
# Matrix([[-0.5*Ctilde + 0.2*Ctilde_1 + 0.3*Ftilde1]])

# %% [markdown]
# Aplicando La Place:
#
# ### $ s \ \tilde{C}_{(s)} = -0.5 \tilde{C}_{(s)} + 0.2 \tilde{C_1}_{(s)} + 0.3 \tilde{F_1}_{(s)} $
#
# ### $ \tilde{C}_{(s)} + 0.5 \tilde{C}_{(s)} = \frac{0.2 \tilde{C_1}_{(s)} + 0.3 \tilde{F_1}_{(s)}}{s} $
#
# ### $ \tilde{C}_{(s)} = \frac{0.2 \tilde{C_1}_{(s)} + 0.3 \tilde{F_1}_{(s)}}{0.5 + s} $
#
# ### $ \tilde{C}_{(s)} = \frac{0.4}{2 s + 1}\tilde{C_1}_{(s)} + \frac{0.6}{2 s + 1} \tilde{F_1}_{(s)} $

# %% [markdown]
# # Itens 4 e 5: Simulação e comparação
#
# Utilize o modelo não linear e simule um cenário no qual o tanque opera em estado estacionário por 2 min quando sofre uma alteração na vazão de entrada F1 que aumenta **1.38** L/min por 5 min e depois retorna ao seu estado estacionário de origem, ou seja, um pulso de duração tp = 5 min é aplicado.

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Anaconda Prompt -> pip install control

import control 
# %matplotlib inline

# %%
# Entradas e Parâmetros:

F1 = 2.00
F2 = 3.00
C1 = 9.00
C2 = 4.00
V = 10.00
Css = 6.00

def modelo1(y,t,u):
    
    # saída (y = C) 
    C = y
           
    # Alteração na vazão com aumento de 1.38 L/min para t >= 2 min e retorna a 0 em t = 7 min
    if t < 2:  
        F1 = u
        
    if  7 > t >= 2:
        F1 = u + 1.38
        
    else:
        F1 = u
        
    # função que define o modelo
    # dydt = f(y,u,t)
        
    f = (F1*(C1-C) + F2*(C2-C))/V
    
    return f

# %%
t0 = 0     # tempo inicial
tf = 20    # tempo final
dt = 0.01  # intervalo de tempo

# vetor de valores de tempo para integração numérica [0, 0.1, 0.2, ..., 20]
tspan = np.arange(t0,tf,dt)
n = len(tspan)

# condição inicial C(0) = Css = 6 kg/L
yss = 6
y0 = yss

# %%
u = 2.0   # F1

y1 = odeint(modelo1, y0, tspan, args=(u,) )

# %%
plt.figure(figsize = (8,5))
plt.title('\n \n Representação Gráfica do Modelo não-linear \n')
plt.plot(tspan,y1,'g',label='Modelo não-linear')
plt.legend()
plt.ylabel('C (kg/L)',fontsize=14)
plt.xlabel('t (min)',fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Item 5: Modelo em La Place
# Simule o mesmo cenário apresentado no item anterior utilizando o modelo em Laplace. Note que neste cenário estamos considerando somente alterações na entrada manipulada $F_{\text {1}}^{\prime}(t)$ e mantendo $C_{\text {1}}^{\prime}(t)$ constante, ou seja, vamos considerar somente:
#
#
# ### $ \frac{C_{\text {out}}^{\prime}(s)}{F_{\text {1}}^{\prime}(s)} = G_1 (s) $
# \
# Apresente uma figura comparando o comportamento dinâmico de ambos os modelos. Pode-se dizer que foi uma boa aproximação? Comente sua resposta. Apresentar gráfcos com as curvas simuladas do modelo linear e não-linear em variável desvio.

# %% [markdown]
# ### $ \tilde{C}_{(s)} = \frac{0.4}{2 s + 1}\tilde{C_1}_{(s)} + \frac{0.6}{2 s + 1} \tilde{F_1}_{(s)} $

# %%
# Definindo os valores de ganho (K) e constante de tempo (tau)

Kp   = 0.6
taup = 2

Kd   = 0.4
taud = 2

# Implementando a função de transferência a partir do módulo control

s = control.tf('s')

Gp = Kp/(taup*s+1)

Gp # Função Transferência do processo
# Out:
# TransferFunction(array([0.6]), array([2, 1]))

# %%
Gd = Kd / (taud*s + 1)
Gd # perturbação
# Out:
# TransferFunction(array([0.4]), array([2, 1]))

# %%
ulinha = np.zeros((1,n)) 

ulinha[0,200:700] = 1.38
tspan, ylin = control.forced_response(Gp, tspan, ulinha)

print(type(ulinha))
print(len(ulinha))
print(ulinha)
# Out:
# <class 'numpy.ndarray'>
# 1
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
plt.figure(figsize = (9,6))
plt.title('\n \n Representação Gráfica do Modelo linear e não-linear \n')
plt.plot(tspan,y1,'r--',label='Modelo não-linear', linewidth=2)
plt.plot(tspan, ylin + yss,'k',label='Modelo linearizado (função de transf.)', linewidth=2)
plt.legend()

plt.axis([0, 20,   6, 7.0])
plt.ylabel('C (kg/L)',fontsize=14)
plt.xlabel('t (min)',fontsize=14)
plt.grid(True, color='k', linestyle='--', linewidth=0.5)

# %% [markdown]
# Na segunda etapa do projeto, iremos implementar a malha de controle para a concentração de sacarose na saída do processo de mistura, assegurando a consistência final do produto. A instrumentação do sistema de controle será definida conforme o diagrama apresentado na Figura abaixo.

# %% [markdown]
# ![Untitled.png](attachment:Untitled.png)

# %% [markdown]
# # Item 7: Função de transferência do modelo considerando o acréscimo do tempo morto.
#
# Admita que a sua equipe identificou que o processo em estudo é afetado por um tempo morto equivalente a $0,5 min$, resultante da instrumentação do sistema. Atualize as funções de transferência do modelo incorporando o tempo morto tanto para a função de transferência do processo quanto para a perturbação.

# %%
dead_time   = 0.5  # tempo morto
d_dead_time = dead_time / dt
n_order     = 2    # aproximação de Padé

# vamos denominar a função de transferência do tempo morto por Hdelay

num, den = control.pade(dead_time,n_order)  # determinando o num. e denom. da aprox. de Padé
Hdelay   = control.tf(num, den)             # colocando na forma de uma função de transf.

Gp_td = Gp * Hdelay # Revisar Item 5
Gd_td = Gd * Hdelay # Revisar Item 5

Hdelay
# Out:
# TransferFunction(array([  1., -12.,  48.]), array([ 1., 12., 48.]))

# %%
Gp_td
# Out:
# TransferFunction(array([ 0.6, -7.2, 28.8]), array([  2.,  25., 108.,  48.]))

# %%
Gd_td
# Out:
# TransferFunction(array([ 0.4, -4.8, 19.2]), array([  2.,  25., 108.,  48.]))

# %% [markdown]
# # Item 8: Cálculo dos parâmetros do controlador PI.
#
# Projete um controlador PI pelos métodos a seguir e calcule a resposta temporal do sistema para uma mudança degrau unitário no setpoint em t = 0 e uma mudança degrau unitário na  carga em $t = 5,38\ min.$
#
# (a) Ziegler e Nichols (1º Método) \
# (b) ITAE (regulador) \
# (c) ITAE (servo) \
# (d) IMC (escolha $\tau_C$ com base nos critérios do grupo)

# %% [markdown]
# ### $ \tilde{C}_{(s)} = \frac{0.4}{2 s + 1}\tilde{C_1}_{(s)} + \frac{0.6}{2 s + 1} \tilde{F_1}_{(s)} $
# \
# Com tempo morto:
#
# ### $ \tilde{C}_{(s)} = \frac{0.4}{2 s + 1}. e^{-0,5s} \tilde{C_1}_{(s)} + \frac{0.6}{2 s + 1}e^{-0,5s} \tilde{F_1}_{(s)} $

# %% [markdown]
# ## Para ZN:
#
# Servo: $ K_c =  \frac{0,9 \tau}{K. \theta} $ \
# \
# $ K_c = 6 $ \
# \
# $ \tau_i = 3.33 \theta $ \
# \
# $ \tau_i = 1,6650 $

# %% [markdown]
# ## Para IMC:
#
# Servo
# $ \tau_c = \frac{\tau}{3} $ \
# \
# $ \tau_i = 2,0000 $
#
#  Caso G da Tabela do IMC:
# $ Kc.K = \frac{\tau}{\tau_c + \theta} $ \
# \
# $ K_c = 5,000 $

# %% [markdown]
# ## ITAE:
#
# |      Servo                | A      |        B |
# |---------------------------|--------|----------|
# | P                         | 0,586  |   -0,916 |
# | I                         | 1,03   |   -0,165 |
#
# $K.Kc = A(\frac{\theta}{\tau})^B $ \
# \
# $ Kc = 3,4772 $
#
# $ \frac{ \tau}{ \tau_i} = A + B(\frac{\theta}{\tau}) $
#
# $ \tau_i = 2,0228 $
#
#
# |      Regulador            | A      | B        |
# |---------------------------|--------|----------|
# | P                         | 0,859  |   -0,977 |
# | I                         | 0,674  |   -0.680 |
#
# $K.Kc = A(\frac{\theta}{\tau})^B $ \
# \
# $ Kc = 5,5469 $
#
# $ \frac{ \tau}{ \tau_i} = A + B(\frac{\theta}{\tau}) $
#
# $ \tau_i = 1,1560 $

# %% [markdown]
# Para o problema, temos: $K$ = 0,6; $\tau$ = 2 min; $t_d$ = 0,5 min, temos:
#
# | Método de sintonia        | Kc     | $\tau i$ |
# |---------------------------|--------|----------|
# | ZN                        | 6,0000 |   1,6650 |
# | ITAE (regulador)          | 5,5469 |   1,1560 |
# | ITAE (servo)              | 3,4772 |   2,0227 |
# | IMC ($\tau_c = \frac{t_d}{3}$)      | 5,0000 |   2,0000  |

# %% [markdown]
# O valor de $\tau_c = \frac{\tau_d}{3}$ foi escolhido para simular uma malha fechada 3 vezes mais rápida que uma malha aberta

# %% [markdown]
# # Item 9: Simulação do sistema em malha fechada.
#
# Utilize o Python e com base no código disponibilizado, execute as simulações para o caso servo e regulador. Lembre-se de executar a aproximação de Padé para que seja possível a simulação com o tempo morto.

# %% [markdown]
# ### Função de transferência em malha fechada
#
# A função de transferência em malha fechada é determinada de acordo com a Equação abaixo:
#
# \begin{equation}
# Y(s) = \dfrac{G_c(s) G(s)}{1 + G_c(s) G(s)} Y_{SP}(s) + \dfrac{G_d(s)}{1 + G_c(s) G(s)} L(s)
# \end{equation}
#
# Para simulação do problema servo, utilizamos:
#
# \begin{equation}
# \dfrac{Y(s)}{ Y_{SP}(s)} = \dfrac{G_c(s) G(s)}{1 + G_c(s) G(s)}
# \end{equation}
#
# Considerando agora o problema regulador, temos:
#
# \begin{equation}
# \dfrac{Y(s)}{ L(s)} = \dfrac{G_d(s)}{1 + G_c(s) G(s)}
# \end{equation}
#
# Para investigarmos o comportamento em malha fechada, simulamos os efeitos separados.

# %% [markdown]
# ### Simulando o problema servo:

# %%
def pid_servo(Kc, tauI, tauD, sint):

    t = np.arange(t0,tf,dt) 
    
    # inicializando e definindo a trajetória de referência
    SP = np.zeros(n) 
    SP[1:n] = 1.0     
    
    # cálculo de Ki = Kc/tauI e Kd = tauD*Kc
    Ki = Kc/tauI
    Kd = Kc*tauD

    # Determinando as ações de controle de forma isolada
    P = Kc
    I = Ki/s 
    D = Kd*s

    # Somando os termos proporcional, integral e derivativo
    Gc = P+I+D 
        
    Gmf = Gp_td*Gc/(1+Gc*Gp_td)
    
    t, y = control.forced_response (Gmf, t, SP)
    
    plt.plot(t, y, label=sint)
    plt.plot(t, SP, 'k--')
    plt.ylim(-0.2, 1.75)
    plt.xlim(-0.5, 7.5)
    plt.title('\n Problema servo (alteração degrau no setpoint) \n')
    plt.ylabel('$y(t)$,$y_{sp}(t)$')
    plt.xlabel('tempo (min)')
    plt.grid('on',linestyle=':')
    plt.legend()

# %%
# cálculo do PI servo para diferentes os parâmetrs de sintonia

plt.figure(figsize = (8,6))
pid_servo (Kc=6.0000, tauI=1.6650, tauD=0, sint= "a) Ziegler e Nichols (1º Método)")
pid_servo (Kc=5.5469, tauI=1.1560, tauD=0, sint= "b) ITAE Regulador")
pid_servo (Kc=3.4772, tauI=2.0222, tauD=0, sint= "c) ITAE Servo")
pid_servo (Kc=5.0000, tauI=2.0000, tauD=0, sint= "d) TauC = td/3")

# %% [markdown]
# De acordo com a simulação feita, o método ZN apresentou uma resposta rápida e levemente oscilatória.
# Para o ITAE servo gerou uma estabilização mais lenta.
# No ITAE Regulador, foram obtidas respostas mais rápidas após uma perturbação no sistema.
# O Método IMC utilizado foi o que apresentou um melhor desempenho a uma alteração degrau, uma vez que teve um comportamento estável e estabilização razoável, comparado aos demais.

# %% [markdown]
# ### Simulando o problema regulador
#
# Utilizando agora a função $G_d(s)$ e considerando que a perturbação $L(s)$ entra no sistema:

# %%
def pid_regulador(Kc,tauI,tauD,sint):

    t = np.arange(t0,tf,dt)     # create time vector   
    
    L  = np.zeros(n) 
    SP = np.zeros(n) 
    
    SP[0:n]  = 0.0              # define setpoint
    L[538: ] = 1.0              # define setpoint
    
    Ki = Kc/tauI
    Kd = Kc*tauD

    P = Kc
    I = Ki/s 
    D = Kd*s

    Gc = P+I+D 
        
    Gmf = Gd_td/(1+Gc*Gp_td)
    t,y = control.forced_response(Gmf,t,L)
    
    plt.subplot(2, 1, 1)
    plt.plot(t, y, label = sint)
    plt.plot(t, SP, 'k--')
    plt.ylim(-0.02, 0.15)
    plt.xlim(4, 17.5)
    plt.title('\n Problema regulador (alteração degrau na carga/perturbação)\n')
    plt.ylabel('$y_{(t)}$, $y_{sp(t)}$')
    plt.xlabel('tempo (min)')
    plt.grid('on',linestyle=':')
    plt.legend()

# %%
plt.figure(figsize = (8,10))
pid_regulador (Kc=6.0000, tauI=1.6650, tauD=0, sint= "a) Ziegler e Nichols (1º Método)")
pid_regulador (Kc=5.5469, tauI=1.1560, tauD=0, sint= "b) ITAE Regulador")
pid_regulador (Kc=3.4772, tauI=2.0222, tauD=0, sint= "c) ITAE Servo")
pid_regulador (Kc=5.0000, tauI=2.0000, tauD=0, sint= "d) TauC = td/3")

# %% [markdown]
# Para uma alteração degrau na perturbação, todos os métodos de sintonia tiveram uma velocidade de resposta praticamente idênticas. Porém, percebe-se algumas diferenças na estabilização. O ITAE Regulador e Ziegler Nichols apresentaram um comportamento oscilatório no início, mas de rápida estabilização. Para o método IMC, houve uma leve oscilação, mas que pode-se dizer desprezível. No ITAE Servo, não houve nenhuma oscilação e foi o que teve o maior tempo de estabilização.
